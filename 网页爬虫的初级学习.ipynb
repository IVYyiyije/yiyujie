# %%
import requests

# %%
r=requests.get('https://www.baidu.com/s?wd=易钰婕')

# %%
r.code
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a88f4df477ed> in <module>()
# ----> 1 r.code
#
# AttributeError: 'Response' object has no attribute 'code'

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r.status_code
# Out:
# 200

# %%
print(r)
# Out:
# <Response [200]>

# %%
r.content
# Out:
# b'<html>\r\n<head>\r\n\t<script>\r\n\t\tlocation.replace(location.href.replace("https://","http://"));\r\n\t</script>\r\n</head>\r\n<body>\r\n\t<noscript><meta http-equiv="refresh" content="0;url=http://www.baidu.com/"></noscript>\r\n</body>\r\n</html>'

# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome()

# %%
browser.get('https://www.baidu.com/s?wd=易钰婕')

# %%
browser.title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e48cdbe5f625> in <module>()
# ----> 1 browser.title
#
# NameError: name 'browser' is not defined

# %%
dir(browser)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
# ...

# %%
dir(browser)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
# ...

# %%
browser.page_source
# Out:
# '<!DOCTYPE html><!--STATUS OK--><html xmlns="http://www.w3.org/1999/xhtml"><head>\n\t\t\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t\t<meta http-equiv="content-type" content="text/html;charset=utf-8" />\n\t\t<meta content="always" name="referrer" />\n        <meta name="theme-color" content="#2932e1" />\n        <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n        <link rel="icon" sizes="any" mask="" href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg" />\n        <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" />\n\t\t\n\t\t\n<title>易钰婕_百度搜索</title>\n\n\t\t\n\n\t\t\n<style data-for="result" type="text/css" id="css_newi_result">body{color:#333;background:#fff;padding:6px 0 0;margin:0;position:relative;min-width:900px}\nbody,th,td,.p1,.p2{font-family:arial}\np,form,ol,ul,li,dl,dt,dd,h3{margin:0;padding:0;list-style:none}\ninput{padding-top:0;padding-bottom:0;-
# ...

# %%
html = browser.page_source
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9c6ca9cbc12c> in <module>()
# ----> 1 html = browser.page_source
#
# NameError: name 'browser' is not defined

# %%
from pyquery import PyQuery as pq

# %%
doc = pq(html)

# %%
doc('#5')
# Out:
# [<{http://www.w3.org/1999/xhtml}div#5.result.c-container.>]

# %%
doc('#5 h3 a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-036581a40d9e> in <module>()
# ----> 1 doc('#5 h4 a')
#
# NameError: name 'doc' is not defined

# %%
doc('#5>h3>a')
# Out:
# []

# %%
doc('#5 h3 a').attr('href')

# %%
doc('div.#4')
# Out:
#   File "<string>", line unknown
# SelectorSyntaxError: Expected ident, got <HASH '4' at 4>

# %%
doc('#4').find('a')
# Out:
# []

# %%
doc('#5')
# Out:
# [<{http://www.w3.org/1999/xhtml}div#5.result.c-container.>]

# %%
doc('#5').html()
# Out:
# '<h3 xmlns="http://www.w3.org/1999/xhtml" class="t"><a data-click="{&#10;&#9;&#9;&#9;\'F\':\'778717EA\',&#10;&#9;&#9;&#9;\'F1\':\'9D73F164\',&#10;&#9;&#9;&#9;\'F2\':\'4CA6DE6B\',&#10;&#9;&#9;&#9;\'F3\':\'54E5243F\',&#10;&#9;&#9;&#9;\'T\':\'1540904671\',&#10;&#9;&#9;&#9;&#9;&#9;&#9;\'y\':\'E6B2FFDB\'&#10;&#9;&#9;&#9; &#10;&#9;&#9;&#9;&#9;&#9;&#9;&#9;&#9;&#9;}" href="http://www.baidu.com/link?url=jmmRdasud0Ys9pN3EgsiR6vTyqgZgY9GcNzG2qZBEmcjB-h6aWVp1UvtS19nkRohMBwZSKAe2dcNKPR6bfau7Umk_KsyOJQwk7Vn4R4JQeK" target="_blank">腾讯这个动漫是在内涵杨幂脚臭吗?后续……马蜂去...</a></h3><div xmlns="http://www.w3.org/1999/xhtml" class="c-abstract"><span class=" newTimeFactor_before_abs m">2018年8月29日\xa0-\xa0</span><em>易钰婕</em>_OFFICIAL 赞了这篇讨论 2018-08-29 12:50:23  愤怒的小马 赞了这篇讨论 2018-08-29 12:49:41 自由吃瓜基地  78357 人聚集在这个小组 加入小组 ...</div><div xmlns="http://www.w3.org/1999/xhtml" class="f13"><a target="_blank" href="http://www.baidu.com/link?url=jmmRdasud0Ys9pN3EgsiR6vTyqgZgY9GcNzG2qZBEmcjB-h6aWVp1UvtS19nkRohMBwZSKAe2dcNKPR6bf
# ...

# %%
doc1=pq(doc('#5').html())

# %%
doc1('h3')

# %%
doc1('h3 a')

# %%
doc1('h3 a').attr('href')
# Out:
# 'http://www.baidu.com/link?url=jmmRdasud0Ys9pN3EgsiR6vTyqgZgY9GcNzG2qZBEmcjB-h6aWVp1UvtS19nkRohMBwZSKAe2dcNKPR6bfau7Umk_KsyOJQwk7Vn4R4JQeK'

# %%
url = doc1('h3 a').attr('href')

# %%
br = webdriver.Chrome()

# %%
br.get(url)

# %%
html1 = br.page_source

# %%
doc2 = pq(html1)

# %%
doc2.text()
# Out:
# '腾讯这个动漫是在内涵杨幂脚臭吗？后续……马蜂去...\nvar _head_start = new Date();\n$(function () { var sidebar = fixed($(\'#content .aside\'), { fixedBound: \'bottom\', gap: 197 }); sidebar.init(); })\nvar _body_start = new Date();\n登录\n注册\n下载豆瓣客户端\n豆瓣\n6.0\n全新发布\n×\n豆瓣\n扫码直接下载\niPhone\n·\nAndroid\n豆瓣\n读书\n电影\n音乐\n同城\n小组\n阅读\nFM\n时间\n豆品\n更多\n豆瓣摄影\n;window._GLOBAL_NAV = { DOUBAN_URL: "https://www.douban.com", N_NEW_NOTIS: 0, N_NEW_DOUMAIL: 0 };\n豆瓣小组\n精选\n文化\n行摄\n娱乐\n时尚\n生活\n科技\n搜索：\n小组、话题\nDo(function(){ var nav = $(\'#db-nav-group\'); var inp=$("#inp-query"),label=inp.closest(".nav-search").find("label");"placeholder"in inp[0]?(label.hide(),inp.attr("placeholder",label.text())):(""!==inp.val()&&label.hide(),inp.parent().click(function(){inp.focus(),label.hide()}).end().focusin(function(){label.hide()}).focusout(function(){""===$.trim(this.value)?label.show():label.hide()}).keydown(function(){label.hide()})),inp.parents("form").submit(function(){if(!$.trim(inp.val()).length)return!1}),nav.find(".lnk-more, 
# ...

# %%
import re
help(re.sub)
# Out:
# Help on function sub in module re:
#
# sub(pattern, repl, string, count=0, flags=0)
#     Return the string obtained by replacing the leftmost
#     non-overlapping occurrences of the pattern in string by the
#     replacement repl.  repl can be either a string or a callable;
#     if a string, backslash escapes in it are processed.  If it is
#     a callable, it's passed the match object and must return
#     a replacement string to be used.

# %%
re.sub('[a-zA-Z0-9\(\)\{\}\!\?\@\%\$\|\+\\\*\'\.\:\=\"\&\;\/\-\~\#]+','',content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-076e293d2de3> in <module>()
# ----> 1 re.sub('[a-zA-Z0-9\(\)\{\}\!\?\@\%\$\|\+\\\*\'\.\:\=\"\&\;\/\-\~\#]+','',content)
#
# NameError: name 'content' is not defined
